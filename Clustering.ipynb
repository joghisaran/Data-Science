# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_excel('EastWestAirlines.xlsx',sheet_name='data')
df
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
df.dtypes
# Out:
# ID#                  int64
# Balance              int64
# Qual_miles           int64
# cc1_miles            int64
# cc2_miles            int64
# cc3_miles            int64
# Bonus_miles          int64
# Bonus_trans          int64
# Flight_miles_12mo    int64
# Flight_trans_12      int64
# Days_since_enroll    int64
# Award?               int64
# dtype: object

# %%
df.isna().sum()
# Out:
# ID#                  0
# Balance              0
# Qual_miles           0
# cc1_miles            0
# cc2_miles            0
# cc3_miles            0
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    0
# Award?               0
# dtype: int64

# %%
z=df.corr(numeric_only=True)
z
# Out:
#                         ID#   Balance  Qual_miles  cc1_miles  cc2_miles  \
# ID#                1.000000 -0.243737   -0.019374  -0.224465   0.020291
# Balance           -0.243737  1.000000    0.108722   0.338344  -0.008804
# Qual_miles        -0.019374  0.108722    1.000000   0.007931  -0.013923
# cc1_miles         -0.224465  0.338344    0.007931   1.000000  -0.068223
# cc2_miles          0.020291 -0.008804   -0.013923  -0.068223   1.000000
# cc3_miles         -0.014707  0.035243   -0.007779   0.060555  -0.006166
# Bonus_miles       -0.203012  0.403487    0.031021   0.825200  -0.003969
# Bonus_trans       -0.146915  0.324935    0.050725   0.608943   0.064399
# Flight_miles_12mo -0.031013  0.217551    0.126774   0.037370   0.010598
# Flight_trans_12   -0.052096  0.255700    0.144004   0.041333   0.028284
# Days_since_enroll -0.964988  0.263129    0.017312   0.230849  -0.005807
# Award?            -0.177901  0.178494    0.095256   0.335457   0.005332
#
# ...

# %%
df.describe()
# Out:
#                ID#       Balance    Qual_miles    cc1_miles    cc2_miles  \
# count  3999.000000  3.999000e+03   3999.000000  3999.000000  3999.000000
# mean   2014.819455  7.360133e+04    144.114529     2.059515     1.014504
# std    1160.764358  1.007757e+05    773.663804     1.376919     0.147650
# min       1.000000  0.000000e+00      0.000000     1.000000     1.000000
# 25%    1010.500000  1.852750e+04      0.000000     1.000000     1.000000
# 50%    2016.000000  4.309700e+04      0.000000     1.000000     1.000000
# 75%    3020.500000  9.240400e+04      0.000000     3.000000     1.000000
# max    4021.000000  1.704838e+06  11148.000000     5.000000     3.000000
#
#          cc3_miles    Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# count  3999.000000    3999.000000   3999.00000        3999.000000
# mean      1.012253   17144.846212     11.60190         460.055764
# std       0.195241   24150.967826      9.60381        1400.209171
# ...

# %%
import seaborn as sns
sns.heatmap(z,annot=True)
# Out:
# <Axes: >

# %%
sns.histplot(z)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.barplot(df)
# Out:
# <Axes: >

# %%
import seaborn as sns
sns.boxplot(data=df)
plt.show()

# %%
n=df.select_dtypes(include='number').columns
print(n)
# Out:
# Index(['ID#', 'Balance', 'Qual_miles', 'cc1_miles', 'cc2_miles', 'cc3_miles',
#        'Bonus_miles', 'Bonus_trans', 'Flight_miles_12mo', 'Flight_trans_12',
#        'Days_since_enroll', 'Award?'],
#       dtype='object')

# %%
# 1st quantile
q1=df[n].quantile(0.25)
q1
# Out:
# ID#                   1010.5
# Balance              18527.5
# Qual_miles               0.0
# cc1_miles                1.0
# cc2_miles                1.0
# cc3_miles                1.0
# Bonus_miles           1250.0
# Bonus_trans              3.0
# Flight_miles_12mo        0.0
# Flight_trans_12          0.0
# Days_since_enroll     2330.0
# Award?                   0.0
# Name: 0.25, dtype: float64

# %%
# 3rd quantile
q3=df[n].quantile(0.75)
q3
# Out:
# ID#                   3020.5
# Balance              92404.0
# Qual_miles               0.0
# cc1_miles                3.0
# cc2_miles                1.0
# cc3_miles                1.0
# Bonus_miles          23800.5
# Bonus_trans             17.0
# Flight_miles_12mo      311.0
# Flight_trans_12          1.0
# Days_since_enroll     5790.5
# Award?                   1.0
# Name: 0.75, dtype: float64

# %%
# Inter Quantile Range
iqr=q3-q1
iqr
# Out:
# ID#                   2010.0
# Balance              73876.5
# Qual_miles               0.0
# cc1_miles                2.0
# cc2_miles                0.0
# cc3_miles                0.0
# Bonus_miles          22550.5
# Bonus_trans             14.0
# Flight_miles_12mo      311.0
# Flight_trans_12          1.0
# Days_since_enroll     3460.5
# Award?                   1.0
# dtype: float64

# %%
outliers = (df[n] < (q1 - 1.5 * iqr)) | (df[n] > (q3 + 1.5 * iqr))
outliers
# Out:
#         ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# 0     False    False       False      False      False      False
# 1     False    False       False      False      False      False
# 2     False    False       False      False      False      False
# 3     False    False       False      False      False      False
# 4     False    False       False      False      False      False
# ...     ...      ...         ...        ...        ...        ...
# 3994  False    False       False      False      False      False
# 3995  False    False       False      False      False      False
# 3996  False    False       False      False      False      False
# 3997  False    False       False      False      False      False
# 3998  False    False       False      False      False      False
#
#       Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# 0           False        False              False            False
# ...

# %%
outliers.sum()
# Out:
# ID#                    0
# Balance              266
# Qual_miles           226
# cc1_miles              0
# cc2_miles             43
# cc3_miles             18
# Bonus_miles          280
# Bonus_trans           63
# Flight_miles_12mo    569
# Flight_trans_12      565
# Days_since_enroll      0
# Award?                 0
# dtype: int64

# %%
df_scaled_data=df.drop('ID#',axis=1)
df_scaled_data
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
# Standardizing the data
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaled_df=scaler.fit_transform(df_scaled_data)
scaled_df
# Out:
# array([[-4.51140783e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.39545434e+00, -7.66919299e-01],
#        [-5.39456874e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.37995704e+00, -7.66919299e-01],
#        [-3.20031232e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.41192021e+00, -7.66919299e-01],
#        ...,
#        [-4.29480975e-05, -1.86298687e-01,  6.83121167e-01, ...,
#         -3.62167870e-01, -1.31560393e+00,  1.30391816e+00],
#        [-1.85606976e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -9.85033311e-02, -1.31608822e+00, -7.66919299e-01],
#        [-7.00507951e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01, -1.31754109e+00, -7.66919299e-01]])

# %%
from sklearn.cluster import KMeans
# Standardize the data
scaler = StandardScaler()
x = scaler.fit_transform(df_scaled_data)


# Apply K-Means with the optimal number of clusters (set manually or from Elbow Method)
optimal_k = 5  # Adjust based on the Elbow curve analysis
kmeans = KMeans(n_clusters=optimal_k, random_state=42, n_init=10)
y_means = kmeans.fit_predict(x)

# Scatter plot for cluster visualization
plt.figure(figsize=(8, 6))

# Assigning colors for up to 8 clusters (modify as needed)
colors = ['pink', 'yellow', 'cyan', 'magenta', 'orange', 'blue', 'red', 'black', 'violet']

for i in range(optimal_k):
    plt.scatter(x[y_means == i, 0], x[y_means == i, 1], s=50, c=colors[i], label=f'Cluster {i}')

# Scatter plot for cluster centers
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], 
            s=200, c='green', marker='X', label='Centroids')

plt.xlabel("Balance (Standardized)")
plt.ylabel("Bonus Miles (Standardized)")
plt.title("Clusters of EastWestAirlines Customers")
plt.legend()
plt.show()

# %%
from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering
# Finding optimal K using the Elbow Method
inertia = []
k_range = range(1, 11)
for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(scaled_df)
    inertia.append(kmeans.inertia_)

# %%
# Plot Elbow Curve
plt.figure(figsize=(8, 5))
plt.plot(k_range, inertia, marker='o', linestyle='--')
plt.xlabel("Number of Clusters (K)")
plt.ylabel("Inertia")
plt.title("Elbow Method for Optimal K in K-Means")
plt.show()

# %%
# Apply K-Means with chosen K
optimal_k = 4  # Adjust based on Elbow method
kmeans = KMeans(n_clusters=optimal_k, random_state=42, n_init=10)
df_scaled_data["KMeans_Cluster"] = kmeans.fit_predict(scaled_df)
df_scaled_data["KMeans_Cluster"]
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       2
#        ..
# 3994    1
# 3995    1
# 3996    2
# 3997    1
# 3998    1
# Name: KMeans_Cluster, Length: 3999, dtype: int32

# %%
# Apply Hierarchical Clustering
hierarchical = AgglomerativeClustering(n_clusters=optimal_k, linkage="ward")
df_scaled_data["Hierarchical_Cluster"] = hierarchical.fit_predict(scaled_df)
df_scaled_data["Hierarchical_Cluster"]
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       0
#        ..
# 3994    1
# 3995    1
# 3996    0
# 3997    1
# 3998    1
# Name: Hierarchical_Cluster, Length: 3999, dtype: int64

# %%
# Apply DBSCAN (Tune eps and min_samples as needed)
dbscan = DBSCAN(eps=1.5, min_samples=5)
df_scaled_data["DBSCAN_Cluster"] = dbscan.fit_predict(scaled_df)
df_scaled_data["DBSCAN_Cluster"]
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       1
#        ..
# 3994    1
# 3995    1
# 3996    1
# 3997    0
# 3998    0
# Name: DBSCAN_Cluster, Length: 3999, dtype: int64

# %%
# Plot Dendrogram
from scipy.cluster.hierarchy import dendrogram, linkage
plt.figure(figsize=(10, 5))
linkage_matrix = linkage(scaled_df, method="ward")
dendrogram(linkage_matrix)
plt.title("Dendrogram for Hierarchical Clustering")
plt.xlabel("Data Points")
plt.ylabel("Distance")
plt.show()

# %%
# Display results
print(df_scaled_data.head())
# Out:
#    Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    28143           0          1          1          1          174
# 1    19244           0          1          1          1          215
# 2    41354           0          1          1          1         4123
# 3    14776           0          1          1          1          500
# 4    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?  \
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1
#
#    KMeans_Cluster  Hierarchical_Cluster  DBSCAN_Cluster
# ...

# %%
# Cluster Analysis and Interpretation
# K-Means Clustering
# Attach cluster labels to original data
df["KMeans_Cluster"] = y_means

# Group by cluster and view the mean of each feature
cluster_summary = df.groupby("KMeans_Cluster").mean()
print(cluster_summary)
# Out:
#                         ID#        Balance   Qual_miles  cc1_miles  cc2_miles  \
# KMeans_Cluster
# 0               2233.347946   43837.679305    43.855450   1.226698   1.019352
# 1               2057.295082  119660.491803  5351.065574   2.000000   1.000000
# 2               1664.866667  138061.400000    78.800000   3.466667   1.000000
# 3               1602.540997  117361.299839    56.463826   3.721061   1.002412
# 4               1757.802721  190251.952381   458.734694   2.224490   1.040816
#
#                 cc3_miles   Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# KMeans_Cluster
# 0                1.000395   4753.095972     6.969194         200.140600
# 1                1.000000  18683.475410    12.229508         963.639344
# 2                4.066667  93927.866667    28.066667         506.666667
# 3                1.001608  39502.667203    18.836817         346.309486
# 4                1.000000  32907.979592    28.231293        5685.823129
#
# ...

# %%
# Hierarchical Clustering
# (This was already done earlier using the dendrogram)
# You can also extract clusters with:
from scipy.cluster.hierarchy import fcluster
labels = fcluster(linkage_matrix, t=5, criterion='maxclust')
df["Hierarchical_Cluster"] = labels
df.groupby("Hierarchical_Cluster").mean()
# Out:
#                               ID#        Balance  Qual_miles  cc1_miles  \
# Hierarchical_Cluster
# 1                     2269.372093   68876.581395   23.255814   1.139535
# 2                     2197.204007   46329.336877    9.028618   1.244072
# 3                     1765.615385  134880.892308  393.323077   2.430769
# 4                     1742.444444  129951.388889   65.666667   3.388889
# 5                     1706.626285  116134.226872  367.779736   3.500000
#
#                       cc2_miles  cc3_miles   Bonus_miles  Bonus_trans  \
# Hierarchical_Cluster
# 1                      2.348837   1.000000  14689.837209    17.534884
# 2                      1.000000   1.000000   4868.112428     6.907604
# 3                      1.000000   1.000000  36582.169231    29.338462
# 4                      1.000000   3.722222  86259.888889    26.222222
# 5                      1.000000   1.000000  36501.331865    17.958884
#
# ...

# %%
# DBSCAN
df["DBSCAN_Cluster"] = dbscan.labels_
df["DBSCAN_Cluster"].value_counts()  # Check cluster distribution
# Out:
# DBSCAN_Cluster
#  0    2411
#  1    1250
# -1     310
#  2      15
#  3       8
#  4       5
# Name: count, dtype: int64

# %%
# Visualization
plt.figure(figsize=(8, 6))
sns.scatterplot(x=df["Balance"], y=df["Bonus_miles"], hue=df["KMeans_Cluster"], palette="Set1", s=60)
plt.title("K-Means Clustering")
plt.xlabel("Balance")
plt.ylabel("Bonus Miles")
plt.legend(title="Cluster")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x=df["Balance"], y=df["Bonus_miles"], hue=df["Hierarchical_Cluster"], palette="Set2", s=60)
plt.title("Hierarchical Clustering")
plt.xlabel("Balance")
plt.ylabel("Bonus Miles")
plt.legend(title="Cluster")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x=df["Balance"], y=df["Bonus_miles"], hue=df["DBSCAN_Cluster"], palette="tab10", s=60)
plt.title("DBSCAN Clustering")
plt.xlabel("Balance")
plt.ylabel("Bonus Miles")
plt.legend(title="Cluster (DBSCAN)")
plt.show()

# %%
# Evaluation and Performance Metrics:
from sklearn.metrics import silhouette_score

# Evaluate K-Means Clustering
kmeans_score = silhouette_score(x, df["KMeans_Cluster"])
print(f"Silhouette Score for K-Means: {kmeans_score:.3f}")

# Evaluate DBSCAN (excluding noise points labeled -1)
mask = df["DBSCAN_Cluster"] != -1  # Filter out noise
if df["DBSCAN_Cluster"].nunique() > 1:
    dbscan_score = silhouette_score(x[mask], df["DBSCAN_Cluster"][mask])
    print(f"Silhouette Score for DBSCAN (excluding noise): {dbscan_score:.3f}")
else:
    print("DBSCAN produced only one cluster or only noise — Silhouette Score not applicable.")
# Out:
# Silhouette Score for K-Means: 0.319
# Silhouette Score for DBSCAN (excluding noise): 0.294

# %% [markdown]
# Conclusion:
# * The clustering analysis using K-Means, Hierarchical Clustering, and DBSCAN demonstrated that each algorithm has unique strengths. K-Means performed best when clusters were well-separated and spherical, giving the highest silhouette score. Hierarchical clustering provided an intuitive visualization through dendrograms, helping identify natural groupings, while DBSCAN effectively detected noise and handled irregular cluster shapes but required careful parameter tuning. Overall, the most suitable method depends on the dataset’s distribution, presence of noise, and the need for interpretability
